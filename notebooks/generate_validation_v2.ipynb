# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns

import sys
import os
import subprocess

# %%
directory = "../simulations/msd_validation_actual/"

# %%
# %cd $directory
# Out:
# /home/ian/Projects/work/md-lv/simulations/msd_validation_actual

# %%
pwd
# Out:
# '/home/ian/Projects/work/md-lv/simulations/msd_validation_actual'

# %%
seed = 0

# %%
for vol in np.linspace(5.0, 11.0, 13):
    print(vol)
    for realization in np.arange(90):
        os.system(f"./../../target/release/md-lv -v {vol} -s 1000000 -t 0.01 -o 100 -i 1000000 --seed {seed}")
        seed += 1
# Out:
# 5.0
# 5.5
# 6.0
# 6.5
# 7.0
# 7.5
# 8.0
# 8.5
# 9.0
# 9.5
# 10.0
# 10.5
# 11.0

# %%
seed
# Out:
# 220

# %%
def fetch_xyz(file, dim=2):
    assert(dim==2 or dim==3)
    output = []
    with open(file, "r") as xyz:
        try:
            while True:
                N = int(xyz.readline())
                xyz.readline()
                arr = np.empty((N, dim))
                for i in np.arange(N):
                    line = xyz.readline()
                    _, x, y, _ = line.split()
                    if dim == 2:
                        arr[i] = np.array([float(x), float(y)])
                    else:
                        arr[i] = np.array([float(x), float(y), float(z)])
                output.append(arr)
        except:
            pass
    return np.array(output)

# %%
def msd_simple(traj, ref=0):
    shape = traj.shape
    timesteps = shape[0]
    N = shape[1]
    oN = 1/N
    dim = shape[2]

    msd = np.zeros((timesteps-ref))
    for i in np.arange(ref, timesteps):
        msd[i] = np.mean(np.square(np.linalg.norm(traj[i] - traj[ref], axis=-1)))
    return msd

def msd_wrap(traj, V, ref=0):
    L=np.sqrt(V)
    L2 = L/2
    shape = traj.shape
    timesteps = shape[0]
    N = shape[1]
    oN = 1/N
    dim = shape[2]

    wrap = np.zeros((N, dim))

    msd = np.zeros((timesteps-ref-1))
    for i in np.arange(ref+1, timesteps):
        diff = traj[i] - traj[i-1]
        cond1 = diff > L2
        cond2 = diff < -L2
        wrap += cond2.astype(int) - cond1.astype(int)

        msd[i-ref-1] = np.mean(np.square(np.linalg.norm(traj[i] + L*wrap - traj[ref], axis=-1)))
    return msd, wrap

def msd_wrap_drift(traj, V, ref=0):
    L=np.sqrt(V)
    L2 = L/2
    shape = traj.shape
    timesteps = shape[0]
    N = shape[1]
    oN = 1/N
    dim = shape[2]

    wrap = np.zeros((N, dim))

    msd = np.zeros((timesteps-ref-1))
    for i in np.arange(ref+1, timesteps):
        diff = traj[i] - traj[i-1]
        cond1 = diff > L2
        cond2 = diff < -L2
        wrap += cond2.astype(int) - cond1.astype(int)

        move = traj[i] + L*wrap - traj[ref]

        drift = np.mean(move, axis=0)

        msd[i-ref-1] = np.mean(np.square(np.linalg.norm(move-drift, axis=-1)))
    return msd, wrap

# %%
import glob

# %%
files = sorted(glob.glob("traj_*t0.0001*_step1000000_*"))

# %%
files
# Out:
# ['traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6010_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6011_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6012_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6013_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6014_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6015_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6016_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6017_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6018_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6019_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6110_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6111_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6112_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6113_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6114_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6115_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6116_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6117_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6118_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6119_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6120_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6121_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6122_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6123_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6124_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6125_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6126_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6127_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6128_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6129_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6130_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6131_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6132_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6133_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6134_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6135_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6136_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6137_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6138_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6139_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6140_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6141_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6142_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6143_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6144_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6145_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6146_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6147_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6148_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6149_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6150_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6151_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6152_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6153_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6154_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6155_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6156_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6157_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6158_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6159_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6160_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6161_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6162_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6163_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6164_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6165_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6166_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6167_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6168_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6169_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6170_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6171_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6172_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6173_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6174_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6175_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6176_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6177_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6178_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6179_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6180_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6181_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6182_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6183_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6184_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6185_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6186_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6187_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6188_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6189_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6190_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6191_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6192_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6193_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6194_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6195_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6196_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6197_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6198_out100.xyz',
#  'traj_n10_v11_t0.0001_step1000000_dt0.001_visc5_seed6199_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6000_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6001_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6002_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6003_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6004_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6005_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6006_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6007_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6008_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6009_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6020_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6021_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6022_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6023_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6024_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6025_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6026_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6027_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6028_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6029_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6030_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6031_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6032_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6033_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6034_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6035_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6036_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6037_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6038_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6039_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6040_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6041_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6042_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6043_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6044_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6045_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6046_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6047_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6048_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6049_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6050_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6051_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6052_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6053_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6054_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6055_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6056_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6057_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6058_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6059_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6060_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6061_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6062_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6063_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6064_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6065_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6066_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6067_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6068_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6069_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6070_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6071_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6072_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6073_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6074_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6075_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6076_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6077_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6078_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6079_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6080_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6081_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6082_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6083_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6084_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6085_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6086_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6087_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6088_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6089_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6090_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6091_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6092_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6093_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6094_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6095_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6096_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6097_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6098_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6099_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6100_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6101_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6102_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6103_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6104_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6105_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6106_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6107_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6108_out100.xyz',
#  'traj_n10_v5_t0.0001_step1000000_dt0.001_visc5_seed6109_out100.xyz']

# %%
len(files)
# Out:
# 200

# %%
from collections import defaultdict

# %%
msd_data = defaultdict(list)
for i in np.arange(len(files)):
    if i%100 == 0:
        print(len(files), i)
    f = files[i]
    vol = float(f.split("_")[2][1:])
    xyz = fetch_xyz(f)
    msd_t, _ = msd_wrap(xyz, vol, ref=100)
    msd_data[vol].append(msd_t)
# Out:
# 1300 0
# 1300 100
# 1300 200
# 1300 300
# 1300 400
# 1300 500
# 1300 600
# 1300 700
# 1300 800
# 1300 900
# 1300 1000
# 1300 1100
# 1300 1200

# %%
msd_data_drift = defaultdict(list)
for i in np.arange(len(files)):
    if i%100 == 0:
        print(len(files), i)
    f = files[i]
    vol = float(f.split("_")[2][1:])
    xyz = fetch_xyz(f)
    msd_t, _ = msd_wrap_drift(xyz, vol, ref=100)
    msd_data_drift[vol].append(msd_t)
# Out:
# 200 0
# 200 100

# %%
plt.plot(np.mean(msds, axis=0))

# %%
plt.plot(msds[2])

# %%
msd_t

# %%
cmap = mpl.cm.viridis
norm = mpl.colors.Normalize(vmin=5, vmax=11)
max_t = 500
for label, dat in msd_data.items():
    plt.plot(np.linspace(0, dat[0].shape[-1]/10, dat[0].shape[-1])[:max_t], np.mean(dat, axis=0), color=cmap(norm(label)), alpha=1)
plt.xlabel("time [s]")
plt.ylabel(r"MSD [$\sigma$]")
plt.colorbar(mpl.cm.ScalarMappable(cmap=cmap, norm=norm), label="Box Area")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-5c243cc25ebc> in <module>
#       2 norm = mpl.colors.Normalize(vmin=5, vmax=11)
#       3 max_t = 500
# ----> 4 for label, dat in msd_data.items():
#       5     plt.plot(np.linspace(0, dat[0].shape[-1]/10, dat[0].shape[-1])[:max_t], np.mean(dat, axis=0), color=cmap(norm(label)), alpha=1)
#       6 plt.xlabel("time [s]")
#
# NameError: name 'msd_data' is not defined

# %%
files[0]
# Out:
# 'traj_n10_v10.5_t0.01_step1000000_dt0.001_visc5_seed1000_out100.xyz'

# %%
cmap = mpl.cm.viridis
norm = mpl.colors.Normalize(vmin=5, vmax=11)
max_t = 900
for label, dat in msd_data_drift.items():
    plt.plot(np.linspace(0, dat[0].shape[-1]/10, dat[0].shape[-1])[:max_t], np.mean(dat, axis=0)[:max_t], color=cmap(norm(label)), alpha=1)
    #break
plt.xlabel("time [s]")
plt.ylabel(r"MSD [$\sigma$]")
plt.colorbar(mpl.cm.ScalarMappable(cmap=cmap, norm=norm), label="Box Area")
plt.savefig("MSD.png")

# %%
dat[0].shape
# Out:
# (9899,)
